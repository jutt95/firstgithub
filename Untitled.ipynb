# %%
#Kaam pip install plotly

###how to put this figure in ppt file to see it correctly


import pandas as pd

# %%
data =pd.read_csv(r"C:\Users\Shafique\Desktop\jupyter_notebook\Chilla_data2_for_plots.csv")

# %%
data.head()
# Out:
#   Gender  Location    Age Qualification_completed    field_of_study  \
# 0    NaN       NaN    NaN                     NaN               NaN
# 1   Male  Pakistan  36-40                 Masters  Natural Sciences
# 2    NaN       NaN    NaN                     NaN               NaN
# 3   Male  Pakistan  26-30               Bachelors             CS/IT
# 4    NaN       NaN    NaN                     NaN               NaN
#
#       Purpose_for_chilla What are you? Blood group   \
# 0                    NaN           NaN          NaN
# 1  to boost my skill set     Unemplyed           B+
# 2                    NaN           NaN          NaN
# 3  to boost my skill set       Student           B+
# 4                    NaN           NaN          NaN
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                         NaN                 NaN  ...
# 1                      U-fone             Prepaid  ...
# 2                         NaN                 NaN  ...
# ...

# %%
data.describe()
# Out:
#        Age (years)-Float/Int  Your Weight in kg? (float)  \
# count             375.000000                  375.000000
# mean               27.576933                   69.321147
# std                 7.224460                   16.264434
# min                 0.000000                    7.000000
# 25%                24.000000                   58.050000
# 50%                27.000000                   68.300000
# 75%                31.000000                   78.500000
# max                90.000000                  161.000000
#
#        Height in cm? Freelancer- (Float)  \
# count                         375.000000
# mean                          162.679282
# std                           172.246844
# min                             0.000000
# 25%                           158.000000
# 50%                           169.000000
# 75%                           175.225000
# max                          1661.160000
#
#        How many hours you code a day? (int) e.g: 5,4,3  \
# ...

# %%
dara fadf =
